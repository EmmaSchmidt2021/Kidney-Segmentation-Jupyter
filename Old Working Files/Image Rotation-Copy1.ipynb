# %%
import PIL 
import numpy as np
import os
import nibabel as nib
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from PIL import Image 
from scipy import ndimage

# %%
data_path = r'C:\Users\UAB\data\AllNIIimages\\'
images = []
segmentations = []
for f in os.listdir(data_path):
  if '_K' in f:
    continue
  else:
    images.append(f)
    segmentations.append(f.replace('.nii', '_K.nii'))

print(images[0], segmentations[0])
images = np.array(images)
segmentations = np.array(segmentations)

indices = np.array(range(len(images))) # we will use this in the next step.
# Out:
# 101934_0_96_L_M.nii 101934_0_96_L_M_K.nii

# %%
path_img = (data_path+'\\'+images[0])
nifti_image = nib.load(path_img)
nifti_data_img = nifti_image.get_fdata()
nifti_img = nifti_data_img[:,:,50]
path_seg = (data_path+'\\'+segmentations[0])
nifti_seg= nib.load(path_seg)
nifti_data_seg = nifti_seg.get_fdata()
nifti_seg = nifti_data_seg[:,:,50]

# %%
nifti_rotate_seg = ndimage.rotate(nifti_seg, 90, mode = 'mirror')
nifti_rotate_img = ndimage.rotate(nifti_img, 90, mode = 'mirror')
print(np.mean(nifti_rotate_img),np.mean(nifti_rotate_seg))
fig, (ax1, ax2) = plt.subplots(1,2,figsize = (10,10))
ax1.imshow(nifti_rotate_img, cmap='gray')
ax2.imshow(nifti_rotate_seg, cmap='gray')
# Out:
# 15.819839477539064 25.921783447265625

# %%
nifti_full= ndimage.rotate(nifti_data_img, 90, mode='mirror')
nifti_full_slice = nifti_full[:,:,50]
plt.imshow(nifti_full_slice, cmap='gray')

# %%
affine = np.eye(4)
nifti_90 = nib.Nifti1Image(roated_img_90, affine)

# %%
nifti_rotate_seg = ndimage.rotate(nifti_seg, 180, mode = 'mirror')
nifti_rotate_img = ndimage.rotate(nifti_img, 180, mode = 'mirror')
fig, (ax1, ax2) = plt.subplots(1,2,figsize = (10,10))
print(np.mean(nifti_rotate_img),np.mean(nifti_rotate_seg))
ax1.imshow(nifti_rotate_img, cmap='gray')
ax2.imshow(nifti_rotate_seg, cmap='gray')

# %%
fig, (ax1, ax2) = plt.subplots(1,2,figsize = (10,10))
print(np.mean(nifti_rotate_img),np.mean(nifti_rotate_seg))
ax1.imshow(nifti_img, cmap='gray')
ax2.imshow(nifti_seg, cmap='gray')

# %%
nifti_rotate_seg = ndimage.rotate(nifti_seg, 15, mode = 'mirror')
nifti_rotate_img = ndimage.rotate(nifti_img, 15, mode = 'mirror')
fig, (ax1, ax2) = plt.subplots(1,2,figsize = (10,10))
print(np.mean(nifti_rotate_img),np.mean(nifti_rotate_seg))
ax1.imshow(nifti_rotate_img, cmap='gray')
ax2.imshow(nifti_rotate_seg, cmap='gray')

# %%
nifti_rotate_seg = ndimage.rotate(nifti_seg, 15, mode = 'constant')
nifti_rotate_img = ndimage.rotate(nifti_img, 15, mode = 'constant')
fig, (ax1, ax2) = plt.subplots(1,2,figsize = (10,10))
print(np.mean(nifti_rotate_img),np.mean(nifti_rotate_seg))
ax1.imshow(nifti_rotate_img, cmap='gray')
ax2.imshow(nifti_rotate_seg, cmap='gray')

# %%
nifti_rotate_seg = ndimage.rotate(nifti_seg, 15, mode = 'wrap')
nifti_rotate_img = ndimage.rotate(nifti_img, 15, mode = 'wrap')
fig, (ax1, ax2) = plt.subplots(1,2,figsize = (10,10))
ax1.imshow(nifti_rotate_img, cmap='gray')
ax2.imshow(nifti_rotate_seg, cmap='gray')
print(np.mean(nifti_rotate_img),np.mean(nifti_rotate_seg))

# %%
nifti_rotate_seg = ndimage.rotate(nifti_seg, 3, mode = 'wrap')
nifti_rotate_img = ndimage.rotate(nifti_img, 3, mode = 'wrap')
fig, (ax1, ax2) = plt.subplots(1,2,figsize = (10,10))
print(np.mean(nifti_rotate_img),np.mean(nifti_rotate_seg))
ax1.imshow(nifti_rotate_img, cmap='gray')
ax2.imshow(nifti_rotate_seg, cmap='gray')
