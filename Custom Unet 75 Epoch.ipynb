# %%
import os
import numpy as np
import nibabel as nib
import tensorflow as tf
import matplotlib.pyplot as plt
from skimage import measure
from skimage.transform import resize
from keras_unet.metrics import dice_coef
from keras_unet.models import custom_unet
from keras_unet.losses import jaccard_distance
from sklearn.model_selection import train_test_split
from PIL import Image
from PIL import ImageOps
import fnmatch
import nibabel as nib
import shutil
# Out:
# -----------------------------------------
# keras-unet init: TF version is >= 2.0.0 - using `tf.keras` instead of `Keras`
# -----------------------------------------

# %%
final_path = r'C:\Users\UAB\data\512_AllNII'
new_size = 512

# %%
patient_folders = []
pt_fnames = []

import os
for root, dirs, files in os.walk(os.path.normpath(final_path), topdown=True):
    for name in files:
        #print(os.path.join(root, name))
        pt_fnames.append(os.path.join(root, name))
print('\nPatient Folders have been identified\n')
#sort through and get only the files with ROI in them
#this eliminates the tiff and 3D files 
#%%
ROI_list = []
for j in range(len(pt_fnames)):
    ROI_name = 'ROI'
    filename = os.path.basename(pt_fnames[j])
    if ROI_name in filename:
        ROI_list.append(pt_fnames[j])
print('\nFilenames have been found and added\n')
# Out:
# Patient Folders have been identified
#
#
# Filenames have been found and added

# %%
path = r'C:\Users\UAB\data\512_AllNII\\'
cyst_names=[]
for root, dirs, files in os.walk(os.path.normpath(path), topdown=True):
    for name in files:
        #print(os.path.join(root, name))
        cyst_names.append(os.path.join(root, name))

C_list = []
for j in range(len(cyst_names)):
    C_name = '_C'
    filename = os.path.basename(cyst_names[j])
    if C_name in filename:
        C_list.append(cyst_names[j])

cyst_path = r"C:\Users\UAB\data\512_Cyst"
#cyst_path = r"C:\Users\schmi\data\NPY Cyst"
for i in range(len(C_list)):
    shutil.move(C_list[i],cyst_path )

# %%
data_path = r'C:\Users\UAB\data\512_AllNII\\'
images = []
segmentations = []
for f in os.listdir(data_path):
  if '_K' in f:
    continue
  else:
    images.append(f)
    segmentations.append(f.replace('.nii', '_K.nii'))

print(images[0], segmentations[0])
images = np.array(images)
segmentations = np.array(segmentations)

indices = np.array(range(len(images))) # we will use this in the next step.
# Out:
# 101934_1_96_L_M.nii 101934_1_96_L_M_K.nii

# %%
print(len(images))
# Out:
# 248

# %%
images = np.array(images[0:80])
segmentations = np.array(segmentations[0:80])
indices = np.array(range(len(images)))

# %%
print(len(images))
# Out:
# 80

# %%
train, test = train_test_split(indices, test_size=0.25) # TODO: split indices into training and test partitions
path = (data_path+'\\'+images[train][0])
nifti_image = nib.load(path)
nifti_data = nifti_image.get_fdata()
nifti_slice = nifti_data[:,:,50]
plt.imshow(nifti_slice, cmap='gray')
plt.title('Opened Nifti File')
plt.show()

# %%
def visualise_data(x, y):
  n=4
  dim = int(np.ceil(np.sqrt(n)))
  fig = plt.figure(figsize=(10,10))
  for i in range(n):
    ax = fig.add_subplot(dim, dim, i+1)
    ax.imshow(x[50*i,:,:,0], cmap='gray')
    contours = measure.find_contours(y[50*i,:,:,0], .99)
    for contour in contours:
      ax.plot(contour[:,1], contour[:,0], color='#FB3640', lw=4)
    ax.axis('off')
    
def retrieve_images_and_segmentations(data_path, images, segmentations, size=(512,512)):
  x = []
  y = []
  for i in range(len(images)):
    seg = read_nifti_file(data_path+segmentations[i])
    img = read_nifti_file(data_path+images[i])
    assert img.shape == seg.shape
    seg = resize(seg,(size[0], size[1], seg.shape[-1]))
    img = resize(img,(size[0], size[1], img.shape[-1]))
    for j in range(seg.shape[-1]):
      # ignore slices that don't have a segmentation
      if np.sum(seg[:,:,j]) == 0:
        continue
      x.append(img[:,:,j])
      y.append(seg[:,:,j])
  x = np.array(x)[:,:,:,np.newaxis]
  y = np.array(y)[:,:,:,np.newaxis]

  # randomly shuffle slices
  m = x.shape[0]
  order = np.random.permutation(m)

  return x[order], y[order]

def read_nifti_file(path):
    nifti_image = nib.load(path)
    nib_data = nifti_image.get_fdata()
    return nib_data

# %%
train, valid = train_test_split(train, test_size=0.25)
example_image = read_nifti_file(data_path+'\\'+images[train][0]) # TODO: read in the first image from the training partition
example_segmentation = read_nifti_file(data_path+'\\'+segmentations[train][0])  # TODO: read in the first segmentation from the training partition

print(example_image.shape, example_segmentation.shape)
# Out:
# (512, 512, 96) (512, 512, 96)

# %%
fig = plt.figure(figsize=(20,10))
ax1 = fig.add_subplot(121)
ax1.imshow(example_image[:,:,40], cmap='gray') # TODO: display the first slice from the image
ax1.axis('off')
ax2 = fig.add_subplot(122)
ax2.imshow(example_segmentation[:,:,40])  # TODO: display the first slice from the segmentation
ax2.axis('off')
plt.show()

# %%
x_train, y_train = retrieve_images_and_segmentations(data_path, images[train], segmentations[train]) #TODO: get the matrices for the training partition
print(x_train.shape, y_train.shape)
# Out:
# (3129, 512, 512, 1) (3129, 512, 512, 1)

# %%
x_valid, y_valid = retrieve_images_and_segmentations(data_path, images[valid], segmentations[valid]) #TODO: get the matrices for the validation partition
print(x_valid.shape, y_valid.shape)
# Out:
# (1073, 512, 512, 1) (1073, 512, 512, 1)

# %%
x_test, y_test = retrieve_images_and_segmentations(data_path, images[test], segmentations[test]) #TODO: get the matrices for the test partition
print(x_test.shape, y_test.shape)
# Out:
# (1459, 512, 512, 1) (1459, 512, 512, 1)

# %%
visualise_data(x_train, y_train)
plt.show()

# %%
model = custom_unet(input_shape=(512, 512, 1))

# %%
# define the checkpoint
from keras.callbacks import ModelCheckpoint
filepath = "model_75E_100I.h5"
checkpoint = ModelCheckpoint(filepath, monitor='loss', verbose=1, save_best_only=True, mode='min')
callbacks_list = [checkpoint]

# %%
model.compile(
  optimizer=tf.keras.optimizers.Adam(learning_rate=3e-4), #TODO: compile the model as described above
  loss=jaccard_distance,
  metrics=[dice_coef])

# %%
history = model.fit(x_train, y_train, 
                    validation_data=(x_valid, y_valid), #TODO: fit the model to the training data, track performance on the validation set and train for 5 epochs.
                    epochs=75)
# Out:
# Epoch 1/75
# 98/98 [==============================] - 46s 398ms/step - loss: -4.9277 - dice_coef: 1.8014 - val_loss: -5.1424 - val_dice_coef: 1.8703
# Epoch 2/75
# 98/98 [==============================] - 34s 351ms/step - loss: -5.4295 - dice_coef: 1.8843 - val_loss: -5.2838 - val_dice_coef: 1.9104
# Epoch 3/75
# 98/98 [==============================] - 34s 352ms/step - loss: -5.5114 - dice_coef: 1.9090 - val_loss: -5.3451 - val_dice_coef: 1.9282
# Epoch 4/75
# 98/98 [==============================] - 34s 352ms/step - loss: -5.5464 - dice_coef: 1.9199 - val_loss: -5.3675 - val_dice_coef: 1.9357
# Epoch 5/75
# 98/98 [==============================] - 35s 352ms/step - loss: -5.5670 - dice_coef: 1.9264 - val_loss: -5.3733 - val_dice_coef: 1.9376
# Epoch 6/75
# 98/98 [==============================] - 35s 353ms/step - loss: -5.5844 - dice_coef: 1.9320 - val_loss: -5.3825 - val_dice_coef: 1.9408
# Epoch 7/75
# 98/98 [==============================] - 35s 356ms/step - loss: -5.5999 - dice_coef: 1.9370 - val_loss: -5.3894 - val_dice_coef: 1.9431
# Epoch 8/75
# 98/98 [==============================] - 35s 359ms/step - loss: -5.6134 - dice_coef: 1.9414 - val_loss: -5.3957 - val_dice_coef: 1.9453
# Epoch 9/75
# 98/98 [==============================] - 35s 359ms/step - loss: -5.6252 - dice_coef: 1.9452 - val_loss: -5.4002 - val_dice_coef: 1.9468
# Epoch 10/75
# 98/98 [==============================] - 35s 358ms/step - loss: -5.6347 - dice_coef: 1.9483 - val_loss: -5.4058 - val_dice_coef: 1.9487
# Epoch 11/75
# 98/98 [==============================] - 35s 358ms/step - loss: -5.6427 - dice_coef: 1.9510 - val_loss: -5.4132 - val_dice_coef: 1.9512
# Epoch 12/75
# 98/98 [==============================] - 35s 352ms/step - loss: -5.6486 - dice_coef: 1.9530 - val_loss: -5.4232 - val_dice_coef: 1.9551
# Epoch 13/75
# 98/98 [==============================] - 34s 352ms/step - loss: -5.6581 - dice_coef: 1.9561 - val_loss: -5.3870 - val_dice_coef: 1.9526
# Epoch 14/75
# 98/98 [==============================] - 34s 351ms/step - loss: -5.6663 - dice_coef: 1.9588 - val_loss: -5.4436 - val_dice_coef: 1.9617
# Epoch 15/75
# 98/98 [==============================] - 34s 352ms/step - loss: -5.6766 - dice_coef: 1.9622 - val_loss: -5.4571 - val_dice_coef: 1.9664
# Epoch 16/75
# 98/98 [==============================] - 34s 352ms/step - loss: -5.6854 - dice_coef: 1.9652 - val_loss: -5.4646 - val_dice_coef: 1.9690
# Epoch 17/75
# 98/98 [==============================] - 34s 351ms/step - loss: -5.6929 - dice_coef: 1.9677 - val_loss: -5.4677 - val_dice_coef: 1.9701
# Epoch 18/75
# 98/98 [==============================] - 34s 351ms/step - loss: -5.6995 - dice_coef: 1.9700 - val_loss: -5.4743 - val_dice_coef: 1.9724
# Epoch 19/75
# 98/98 [==============================] - 35s 359ms/step - loss: -5.7047 - dice_coef: 1.9717 - val_loss: -5.4854 - val_dice_coef: 1.9763
# Epoch 20/75
# 98/98 [==============================] - 35s 360ms/step - loss: -5.7084 - dice_coef: 1.9730 - val_loss: -5.4736 - val_dice_coef: 1.9722
# Epoch 21/75
# 98/98 [==============================] - 35s 356ms/step - loss: -5.7118 - dice_coef: 1.9742 - val_loss: -5.4889 - val_dice_coef: 1.9776
# Epoch 22/75
# 98/98 [==============================] - 34s 352ms/step - loss: -5.7170 - dice_coef: 1.9760 - val_loss: -5.4960 - val_dice_coef: 1.9803
# Epoch 23/75
# 98/98 [==============================] - 34s 352ms/step - loss: -5.7218 - dice_coef: 1.9775 - val_loss: -5.4921 - val_dice_coef: 1.9788
# Epoch 24/75
# 98/98 [==============================] - 34s 351ms/step - loss: -5.7245 - dice_coef: 1.9785 - val_loss: -5.4925 - val_dice_coef: 1.9788
# Epoch 25/75
# 98/98 [==============================] - 34s 351ms/step - loss: -5.7294 - dice_coef: 1.9801 - val_loss: -5.5004 - val_dice_coef: 1.9817
# Epoch 26/75
# 98/98 [==============================] - 34s 351ms/step - loss: -5.7309 - dice_coef: 1.9806 - val_loss: -5.5022 - val_dice_coef: 1.9823
# Epoch 27/75
# 98/98 [==============================] - 34s 351ms/step - loss: -5.7332 - dice_coef: 1.9814 - val_loss: -5.5001 - val_dice_coef: 1.9815
# Epoch 28/75
# 98/98 [==============================] - 34s 352ms/step - loss: -5.7344 - dice_coef: 1.9818 - val_loss: -5.5051 - val_dice_coef: 1.9834
# Epoch 29/75
# 98/98 [==============================] - 34s 352ms/step - loss: -5.7371 - dice_coef: 1.9827 - val_loss: -5.5058 - val_dice_coef: 1.9836
# Epoch 30/75
# 98/98 [==============================] - 34s 352ms/step - loss: -5.7384 - dice_coef: 1.9831 - val_loss: -5.5064 - val_dice_coef: 1.9838
# Epoch 31/75
# 98/98 [==============================] - 34s 351ms/step - loss: -5.7400 - dice_coef: 1.9837 - val_loss: -5.5077 - val_dice_coef: 1.9842
# Epoch 32/75
# 98/98 [==============================] - 34s 351ms/step - loss: -5.7360 - dice_coef: 1.9824 - val_loss: -5.5090 - val_dice_coef: 1.9847
# Epoch 33/75
# 98/98 [==============================] - 34s 351ms/step - loss: -5.7398 - dice_coef: 1.9836 - val_loss: -5.5095 - val_dice_coef: 1.9850
# Epoch 34/75
# 98/98 [==============================] - 34s 351ms/step - loss: -5.7415 - dice_coef: 1.9842 - val_loss: -5.5088 - val_dice_coef: 1.9846
# Epoch 35/75
# 98/98 [==============================] - 34s 351ms/step - loss: -5.7428 - dice_coef: 1.9847 - val_loss: -5.5090 - val_dice_coef: 1.9847
# Epoch 36/75
# 98/98 [==============================] - 34s 351ms/step - loss: -5.7440 - dice_coef: 1.9850 - val_loss: -5.5126 - val_dice_coef: 1.9860
# Epoch 37/75
# 98/98 [==============================] - 34s 351ms/step - loss: -5.7446 - dice_coef: 1.9853 - val_loss: -5.5127 - val_dice_coef: 1.9860
# Epoch 38/75
# 98/98 [==============================] - 34s 351ms/step - loss: -5.7449 - dice_coef: 1.9853 - val_loss: -5.5115 - val_dice_coef: 1.9856
# Epoch 39/75
# 98/98 [==============================] - 34s 352ms/step - loss: -5.7426 - dice_coef: 1.9846 - val_loss: -5.5118 - val_dice_coef: 1.9859
# Epoch 40/75
# 98/98 [==============================] - 35s 353ms/step - loss: -5.7444 - dice_coef: 1.9852 - val_loss: -5.5107 - val_dice_coef: 1.9859
# Epoch 41/75
# 98/98 [==============================] - 35s 354ms/step - loss: -5.7437 - dice_coef: 1.9849 - val_loss: -5.5132 - val_dice_coef: 1.9863
# Epoch 42/75
# 98/98 [==============================] - 35s 353ms/step - loss: -5.7465 - dice_coef: 1.9859 - val_loss: -5.5120 - val_dice_coef: 1.9857
# Epoch 43/75
# 98/98 [==============================] - 35s 353ms/step - loss: -5.7476 - dice_coef: 1.9862 - val_loss: -5.5136 - val_dice_coef: 1.9865
# Epoch 44/75
# 98/98 [==============================] - 35s 353ms/step - loss: -5.7475 - dice_coef: 1.9862 - val_loss: -5.5132 - val_dice_coef: 1.9863
# Epoch 45/75
# 98/98 [==============================] - 35s 358ms/step - loss: -5.7485 - dice_coef: 1.9865 - val_loss: -5.5151 - val_dice_coef: 1.9869
# Epoch 46/75
# 98/98 [==============================] - 35s 360ms/step - loss: -5.7491 - dice_coef: 1.9868 - val_loss: -5.5159 - val_dice_coef: 1.9872
# Epoch 47/75
# 98/98 [==============================] - 35s 357ms/step - loss: -5.7488 - dice_coef: 1.9867 - val_loss: -5.5162 - val_dice_coef: 1.9873
# Epoch 48/75
# 98/98 [==============================] - 34s 351ms/step - loss: -5.7492 - dice_coef: 1.9868 - val_loss: -5.5161 - val_dice_coef: 1.9874
# Epoch 49/75
# 98/98 [==============================] - 34s 352ms/step - loss: -5.7492 - dice_coef: 1.9868 - val_loss: -5.5159 - val_dice_coef: 1.9872
# Epoch 50/75
# 98/98 [==============================] - 34s 352ms/step - loss: -5.7503 - dice_coef: 1.9872 - val_loss: -5.5167 - val_dice_coef: 1.9874
# Epoch 51/75
# 98/98 [==============================] - 34s 352ms/step - loss: -5.7495 - dice_coef: 1.9869 - val_loss: -5.5146 - val_dice_coef: 1.9867
# Epoch 52/75
# 98/98 [==============================] - 34s 352ms/step - loss: -5.7495 - dice_coef: 1.9869 - val_loss: -5.5145 - val_dice_coef: 1.9867
# Epoch 53/75
# 98/98 [==============================] - 34s 352ms/step - loss: -5.7499 - dice_coef: 1.9871 - val_loss: -5.5162 - val_dice_coef: 1.9872
# Epoch 54/75
# 98/98 [==============================] - 34s 352ms/step - loss: -5.7497 - dice_coef: 1.9869 - val_loss: -5.5145 - val_dice_coef: 1.9871
# Epoch 55/75
# 98/98 [==============================] - 35s 352ms/step - loss: -5.7505 - dice_coef: 1.9872 - val_loss: -5.5148 - val_dice_coef: 1.9870
# Epoch 56/75
# 98/98 [==============================] - 34s 351ms/step - loss: -5.7511 - dice_coef: 1.9875 - val_loss: -5.5172 - val_dice_coef: 1.9876
# Epoch 57/75
# 98/98 [==============================] - 34s 351ms/step - loss: -5.7496 - dice_coef: 1.9869 - val_loss: -5.5120 - val_dice_coef: 1.9859
# Epoch 58/75
# 98/98 [==============================] - 34s 352ms/step - loss: -5.7500 - dice_coef: 1.9871 - val_loss: -5.5176 - val_dice_coef: 1.9878
# Epoch 59/75
# 98/98 [==============================] - 34s 351ms/step - loss: -5.7513 - dice_coef: 1.9875 - val_loss: -5.5173 - val_dice_coef: 1.9877
# Epoch 60/75
# 98/98 [==============================] - 34s 352ms/step - loss: -5.7515 - dice_coef: 1.9876 - val_loss: -5.5163 - val_dice_coef: 1.9876
# Epoch 61/75
# 98/98 [==============================] - 34s 352ms/step - loss: -5.7511 - dice_coef: 1.9875 - val_loss: -5.5178 - val_dice_coef: 1.9880
# Epoch 62/75
# 98/98 [==============================] - 34s 351ms/step - loss: -5.7528 - dice_coef: 1.9880 - val_loss: -5.5169 - val_dice_coef: 1.9876
# Epoch 63/75
# 98/98 [==============================] - 34s 352ms/step - loss: -5.7528 - dice_coef: 1.9880 - val_loss: -5.5177 - val_dice_coef: 1.9880
# Epoch 64/75
# 98/98 [==============================] - 1404s 14s/step - loss: -5.7527 - dice_coef: 1.9880 - val_loss: -5.5174 - val_dice_coef: 1.9879
# Epoch 65/75
# 98/98 [==============================] - 34s 344ms/step - loss: -5.7530 - dice_coef: 1.9881 - val_loss: -5.5164 - val_dice_coef: 1.9876
# Epoch 66/75
# 98/98 [==============================] - 34s 347ms/step - loss: -5.7537 - dice_coef: 1.9883 - val_loss: -5.5170 - val_dice_coef: 1.9878
# Epoch 67/75
# 98/98 [==============================] - 34s 350ms/step - loss: -5.7533 - dice_coef: 1.9882 - val_loss: -5.5189 - val_dice_coef: 1.9882
# Epoch 68/75
# 98/98 [==============================] - 34s 352ms/step - loss: -5.7532 - dice_coef: 1.9881 - val_loss: -5.5166 - val_dice_coef: 1.9877
# Epoch 69/75
# 98/98 [==============================] - 35s 352ms/step - loss: -5.7513 - dice_coef: 1.9875 - val_loss: -5.5164 - val_dice_coef: 1.9877
# Epoch 70/75
# 98/98 [==============================] - 35s 353ms/step - loss: -5.7527 - dice_coef: 1.9879 - val_loss: -5.5182 - val_dice_coef: 1.9880
# Epoch 71/75
# 98/98 [==============================] - 35s 353ms/step - loss: -5.7536 - dice_coef: 1.9883 - val_loss: -5.5177 - val_dice_coef: 1.9880
# Epoch 72/75
# 98/98 [==============================] - 34s 352ms/step - loss: -5.7534 - dice_coef: 1.9882 - val_loss: -5.5163 - val_dice_coef: 1.9876
# Epoch 73/75
# 98/98 [==============================] - 34s 352ms/step - loss: -5.7542 - dice_coef: 1.9885 - val_loss: -5.5169 - val_dice_coef: 1.9879
# Epoch 74/75
# 98/98 [==============================] - 34s 352ms/step - loss: -5.7543 - dice_coef: 1.9885 - val_loss: -5.5192 - val_dice_coef: 1.9884
# Epoch 75/75
# 98/98 [==============================] - 34s 351ms/step - loss: -5.7539 - dice_coef: 1.9884 - val_loss: -5.5180 - val_dice_coef: 1.9882

# %%
# %matplotlib inline
plt.plot(range(len(history.history['loss'])), history.history['loss'], '-') #TODO: plot the training loss learning curve
plt.plot(range(len(history.history['val_loss'])), history.history['val_loss'], '-') #TODO: plot the validation loss learning curve
plt.xlabel('epoch')
plt.xlabel('Jaccard loss')

plt.show()

# %%
plt.plot(range(len(history.history['dice_coef'])), history.history['dice_coef'], '-') #TODO: plot the training dice_coef learning curve

plt.plot(range(len(history.history['val_dice_coef'])), history.history['val_dice_coef'], '-') #TODO: plot the validation dice_coef learning curve
plt.xlabel('epoch')
plt.xlabel('Dice coefficient')
# Out:
# Text(0.5, 0, 'Dice coefficient')

# %%
from keras.models import Sequential, load_model
model.save('model_75E_100I.h5')

# %%
model = custom_unet(input_shape=(512,512,1))
model.load_weights('model_75E_100I.h5')

# %%
def visualise_data(x, y):
  n=4
  dim = int(np.ceil(np.sqrt(n)))
  fig = plt.figure(figsize=(20,10))
  for i in range(n):
    ax = fig.add_subplot(dim, dim, i+1)
    ax.imshow(x[50*i,:,:,0], cmap='gray')
    contours = measure.find_contours(y[50*i,:,:,0], .99)
    for contour in contours:
      ax.plot(contour[:,1], contour[:,0], color='#FB3640', lw=4)
    ax.axis('off')


def visualise_data_and_prediction(x, y, y_pred):
  n=4
  dim = int(np.ceil(np.sqrt(n)))
  fig = plt.figure(figsize=(20,10))
  for i in range(n):
    ax = fig.add_subplot(dim, dim, i+1)
    ax.imshow(x[50*i,:,:,0], cmap='gray')
    contours = measure.find_contours(y[50*i,:,:,0], .99)
    for j,contour in enumerate(contours):
      ax.plot(contour[:,1], contour[:,0], color='#FB3640', lw=4)
    contours = measure.find_contours(y_pred[50*i,:,:,0], .99)
    for contour in contours:
      ax.plot(contour[:,1], contour[:,0], color='#35A7FF', lw=4)
    ax.axis('off')

# %%
y_pred_train = model.predict(x_train) #TODO: predict on the training set
y_pred_train = y_pred_train.astype('float')

# %%
visualise_data_and_prediction(x_train, y_train, y_pred_train)

# %%
print('Dice:')
print(np.array(dice_coef(y_train, y_pred_train.astype('float'))))
# Out:
# Dice:
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# <ipython-input-28-7bf19b32aa06> in <module>
#       1 print('Dice:')
# ----> 2 print(np.array(dice_coef(y_train, y_pred_train.astype('float'))))
#
# ~\anaconda3\envs\TF23\lib\site-packages\keras_unet\metrics.py in dice_coef(y_true, y_pred, smooth)
#      38 def dice_coef(y_true, y_pred, smooth=1.):
#      39     y_true_f = K.flatten(y_true)
# ---> 40     y_pred_f = K.flatten(y_pred)
#      41     intersection = K.sum(y_true_f * y_pred_f)
#      42     return (2. * intersection + smooth) / (
#
# ~\anaconda3\envs\TF23\lib\site-packages\tensorflow\python\util\traceback_utils.py in error_handler(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
# --> 153       raise e.with_traceback(filtered_tb) from None
#     154     finally:
#     155       del filtered_tb
#
# ~\anaconda3\envs\TF23\lib\site-packages\keras\backend.py in flatten(x)
#    3648
#    3649   """
# -> 3650   return tf.reshape(x, [-1])
#    3651
#    3652
#
# InternalError: Failed copying input tensor from /job:localhost/replica:0/task:0/device:CPU:0 to /job:localhost/replica:0/task:0/device:GPU:0 in order to run _EagerConst: Dst tensor is not initialized.

# %%
y_pred_valid = model.predict(x_valid) #TODO: predict on the validation set
y_pred_valid = y_pred_valid.astype('float') # casting to type float to avoid ValueError later
#print('Dice:')
#print(np.array(dice_coef(y_valid, y_pred_valid.astype('float'))))
# Out:
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# <ipython-input-29-c686bd118f09> in <module>
# ----> 1 y_pred_valid = model.predict(x_valid) #TODO: predict on the validation set
#       2 y_pred_valid = y_pred_valid.astype('float') # casting to type float to avoid ValueError later
#       3 #print('Dice:')
#       4 #print(np.array(dice_coef(y_valid, y_pred_valid.astype('float'))))
#
# ~\anaconda3\envs\TF23\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67       raise e.with_traceback(filtered_tb) from None
#      68     finally:
#      69       del filtered_tb
#
# ~\anaconda3\envs\TF23\lib\site-packages\tensorflow\python\framework\constant_op.py in convert_to_eager_tensor(value, ctx, dtype)
#     100       dtype = dtypes.as_dtype(dtype).as_datatype_enum
#     101   ctx.ensure_initialized()
# --> 102   return ops.EagerTensor(value, ctx.device_name, dtype)
#     103
#     104
#
# InternalError: Failed copying input tensor from /job:localhost/replica:0/task:0/device:CPU:0 to /job:localhost/replica:0/task:0/device:GPU:0 in order to run _EagerConst: Dst tensor is not initialized.

# %%
visualise_data_and_prediction(x_valid, y_valid, y_pred_valid)

# %%
image = nib.load(r"C:\Users\UAB\data\512_AllNII\101934_1_96_L_M.nii")

# %%
image_data = image.get_fdata()
data = np.asarray(image_data).astype(np.float32)

# %%
print(data.shape)
# Out:
# (512, 512, 96)

# %%
image_prediction = model.predict(data)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-46-2365fcf74707> in <module>
# ----> 1 image_prediction = model.predict(data)
#
# ~\anaconda3\envs\TF23\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67       raise e.with_traceback(filtered_tb) from None
#      68     finally:
#      69       del filtered_tb
#
# ~\anaconda3\envs\TF23\lib\site-packages\tensorflow\python\framework\func_graph.py in autograph_handler(*args, **kwargs)
#    1145           except Exception as e:  # pylint:disable=broad-except
#    1146             if hasattr(e, "ag_error_metadata"):
# -> 1147               raise e.ag_error_metadata.to_exception(e)
#    1148             else:
#    1149               raise
#
# ValueError: in user code:
#
#     File "C:\Users\UAB\anaconda3\envs\TF23\lib\site-packages\keras\engine\training.py", line 1801, in predict_function  *
#         return step_function(self, iterator)
#     File "C:\Users\UAB\anaconda3\envs\TF23\lib\site-packages\keras\engine\training.py", line 1790, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "C:\Users\UAB\anaconda3\envs\TF23\lib\site-packages\keras\engine\training.py", line 1783, in run_step  **
#         outputs = model.predict_step(data)
#     File "C:\Users\UAB\anaconda3\envs\TF23\lib\site-packages\keras\engine\training.py", line 1751, in predict_step
#         return self(x, training=False)
#     File "C:\Users\UAB\anaconda3\envs\TF23\lib\site-packages\keras\utils\traceback_utils.py", line 67, in error_handler
#         raise e.with_traceback(filtered_tb) from None
#     File "C:\Users\UAB\anaconda3\envs\TF23\lib\site-packages\keras\engine\input_spec.py", line 264, in assert_input_compatibility
#         raise ValueError(f'Input {input_index} of layer "{layer_name}" is '
#
#     ValueError: Input 0 of layer "model_1" is incompatible with the layer: expected shape=(None, 512, 512, 1), found shape=(32, 512, 96)

# %%
from automouse_model import automouseTKV_model_2
model = automouseTKV_model_2()
model.compile(
  optimizer=tf.keras.optimizers.Adam(learning_rate=3e-4), #TODO: compile the model as described above
  loss=jaccard_distance,
  metrics=[dice_coef])

# %%
history = model.fit(x_train, y_train, 
                    validation_data=(x_valid, y_valid), #TODO: fit the model to the training data, track performance on the validation set and train for 5 epochs.
                    epochs=10)
# Out:
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# <ipython-input-51-96ecfe75c580> in <module>
# ----> 1 history = model.fit(x_train, y_train,
#       2                     validation_data=(x_valid, y_valid), #TODO: fit the model to the training data, track performance on the validation set and train for 5 epochs.
#       3                     epochs=10)
#
# ~\anaconda3\envs\TF23\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67       raise e.with_traceback(filtered_tb) from None
#      68     finally:
#      69       del filtered_tb
#
# ~\anaconda3\envs\TF23\lib\site-packages\tensorflow\python\framework\constant_op.py in convert_to_eager_tensor(value, ctx, dtype)
#     100       dtype = dtypes.as_dtype(dtype).as_datatype_enum
#     101   ctx.ensure_initialized()
# --> 102   return ops.EagerTensor(value, ctx.device_name, dtype)
#     103
#     104
#
# InternalError: Failed copying input tensor from /job:localhost/replica:0/task:0/device:CPU:0 to /job:localhost/replica:0/task:0/device:GPU:0 in order to run _EagerConst: Dst tensor is not initialized.
