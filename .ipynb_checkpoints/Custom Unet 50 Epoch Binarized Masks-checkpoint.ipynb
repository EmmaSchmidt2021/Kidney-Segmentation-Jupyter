# %%
import os
import numpy as np
import nibabel as nib
import tensorflow as tf
import matplotlib.pyplot as plt
from skimage import measure
from skimage.transform import resize
from keras_unet.metrics import dice_coef
from keras_unet.models import custom_unet
from keras_unet.losses import jaccard_distance
from sklearn.model_selection import train_test_split
from PIL import Image
from PIL import ImageOps
import fnmatch
import nibabel as nib
import shutil
# Out:
# -----------------------------------------
# keras-unet init: TF version is >= 2.0.0 - using `tf.keras` instead of `Keras`
# -----------------------------------------

# %%
data_path = r'C:\Users\UAB\data\NII_Binarized'
images = []
segmentations = []
for f in os.listdir(data_path):
  if '_K' in f:
    continue
  else:
    images.append(f)
    segmentations.append(f.replace('.nii', '_K.nii'))

print(images[0], segmentations[0])
images = np.array(images)
segmentations = np.array(segmentations)

indices = np.array(range(len(images))) # we will use this in the next step.
# Out:
# 101934_1_96_L_M.nii 101934_1_96_L_M_K.nii

# %%
print(len(images))
# Out:
# 247

# %%
images = np.array(images[0:80])
segmentations = np.array(segmentations[0:80])
indices = np.array(range(len(images)))

# %%
print(len(images))
# Out:
# 80

# %%
train, test = train_test_split(indices, test_size=0.25) # TODO: split indices into training and test partitions
path = (data_path+'\\'+images[train][0])
nifti_image = nib.load(path)
nifti_data = nifti_image.get_fdata()
nifti_slice = nifti_data[:,:,50]
plt.imshow(nifti_slice, cmap='gray')
plt.title('Opened Nifti File')
plt.show()

# %%
def visualise_data(x, y):
  n=4
  dim = int(np.ceil(np.sqrt(n)))
  fig = plt.figure(figsize=(10,10))
  for i in range(n):
    ax = fig.add_subplot(dim, dim, i+1)
    ax.imshow(x[50*i,:,:,0], cmap='gray')
    contours = measure.find_contours(y[50*i,:,:,0], .99)
    for contour in contours:
      ax.plot(contour[:,1], contour[:,0], color='#FB3640', lw=4)
    ax.axis('off')
    
def retrieve_images_and_segmentations(data_path, images, segmentations, size=(512,512)):
  x = []
  y = []
  for i in range(len(images)):
    seg = read_nifti_file(data_path+segmentations[i])
    img = read_nifti_file(data_path+images[i])
    assert img.shape == seg.shape
    seg = resize(seg,(size[0], size[1], seg.shape[-1]))
    img = resize(img,(size[0], size[1], img.shape[-1]))
    for j in range(seg.shape[-1]):
      # ignore slices that don't have a segmentation
      if np.sum(seg[:,:,j]) == 0:
        continue
      x.append(img[:,:,j])
      y.append(seg[:,:,j])
  x = np.array(x)[:,:,:,np.newaxis]
  y = np.array(y)[:,:,:,np.newaxis]

  # randomly shuffle slices
  m = x.shape[0]
  order = np.random.permutation(m)

  return x[order], y[order]

def read_nifti_file(path):
    nifti_image = nib.load(path)
    nib_data = nifti_image.get_fdata()
    return nib_data

# %%
train, valid = train_test_split(train, test_size=0.25)
example_image = read_nifti_file(data_path+'\\'+images[train][0]) # TODO: read in the first image from the training partition
example_segmentation = read_nifti_file(data_path+'\\'+segmentations[train][0])  # TODO: read in the first segmentation from the training partition

print(example_image.shape, example_segmentation.shape)
# Out:
# (512, 512, 105) (512, 512, 105)

# %%
fig = plt.figure(figsize=(20,10))
ax1 = fig.add_subplot(121)
ax1.imshow(example_image[:,:,40], cmap='gray') # TODO: display the first slice from the image
ax1.axis('off')
ax2 = fig.add_subplot(122)
ax2.imshow(example_segmentation[:,:,40])  # TODO: display the first slice from the segmentation
ax2.axis('off')
plt.show()

# %%
data_path = r'C:\Users\UAB\data\NII_Binarized\\'
x_train, y_train = retrieve_images_and_segmentations(data_path, images[train], segmentations[train]) #TODO: get the matrices for the training partition
print(x_train.shape, y_train.shape)
# Out:
# (3143, 512, 512, 1) (3143, 512, 512, 1)

# %%
x_valid, y_valid = retrieve_images_and_segmentations(data_path, images[valid], segmentations[valid]) #TODO: get the matrices for the validation partition
print(x_valid.shape, y_valid.shape)
# Out:
# (1127, 512, 512, 1) (1127, 512, 512, 1)

# %%
x_test, y_test = retrieve_images_and_segmentations(data_path, images[test], segmentations[test]) #TODO: get the matrices for the test partition
print(x_test.shape, y_test.shape)
# Out:
# (1391, 512, 512, 1) (1391, 512, 512, 1)

# %%
visualise_data(x_train, y_train)
plt.show()

# %%
model = custom_unet(input_shape=(512, 512, 1))

# %%
# define the checkpoint
from keras.callbacks import ModelCheckpoint
filepath = "10epoch_binaryMask.h5"
checkpoint = ModelCheckpoint(filepath, monitor='loss', verbose=1, save_best_only=True, mode='min')
callbacks_list = [checkpoint]

# %%
model.compile(
  optimizer=tf.keras.optimizers.Adam(learning_rate=3e-4), #TODO: compile the model as described above
  loss=jaccard_distance,
  metrics=[dice_coef])

# %%
history = model.fit(x_train, y_train, 
                    validation_data=(x_valid, y_valid), #TODO: fit the model to the training data, track performance on the validation set and train for 5 epochs.
                    epochs=10)
# Out:
# Epoch 1/10
# 99/99 [==============================] - 50s 398ms/step - loss: 0.3465 - dice_coef: 0.1144 - val_loss: 0.1283 - val_dice_coef: 0.2538
# Epoch 2/10
# 99/99 [==============================] - 35s 352ms/step - loss: 0.2050 - dice_coef: 0.1762 - val_loss: 0.0908 - val_dice_coef: 0.3246
# Epoch 3/10
# 99/99 [==============================] - 35s 354ms/step - loss: 0.1674 - dice_coef: 0.2076 - val_loss: 0.0877 - val_dice_coef: 0.3323
# Epoch 4/10
# 99/99 [==============================] - 35s 355ms/step - loss: 0.1417 - dice_coef: 0.2359 - val_loss: 0.0869 - val_dice_coef: 0.3343
# Epoch 5/10
# 99/99 [==============================] - 35s 355ms/step - loss: 0.1238 - dice_coef: 0.2611 - val_loss: 0.0844 - val_dice_coef: 0.3408
# Epoch 6/10
# 99/99 [==============================] - 35s 356ms/step - loss: 0.1101 - dice_coef: 0.2840 - val_loss: 0.0843 - val_dice_coef: 0.3412
# Epoch 7/10
# 99/99 [==============================] - 35s 356ms/step - loss: 0.0916 - dice_coef: 0.3210 - val_loss: 0.0407 - val_dice_coef: 0.5155
# Epoch 8/10
# 99/99 [==============================] - 35s 356ms/step - loss: 0.0735 - dice_coef: 0.3699 - val_loss: 0.0866 - val_dice_coef: 0.3348
# Epoch 9/10
# 99/99 [==============================] - 36s 359ms/step - loss: 0.0598 - dice_coef: 0.4165 - val_loss: 0.0213 - val_dice_coef: 0.6657
# Epoch 10/10
# 99/99 [==============================] - 35s 355ms/step - loss: 0.0479 - dice_coef: 0.4709 - val_loss: 0.0201 - val_dice_coef: 0.6811

# %%
# %matplotlib inline
plt.plot(range(len(history.history['loss'])), history.history['loss'], '-') #TODO: plot the training loss learning curve
plt.plot(range(len(history.history['val_loss'])), history.history['val_loss'], '-') #TODO: plot the validation loss learning curve
plt.xlabel('epoch')
plt.xlabel('Jaccard loss')

plt.show()

# %%
plt.plot(range(len(history.history['dice_coef'])), history.history['dice_coef'], '-') #TODO: plot the training dice_coef learning curve

plt.plot(range(len(history.history['val_dice_coef'])), history.history['val_dice_coef'], '-') #TODO: plot the validation dice_coef learning curve
plt.xlabel('epoch')
plt.xlabel('Dice coefficient')
# Out:
# Text(0.5, 0, 'Dice coefficient')

# %%
from keras.models import Sequential, load_model
model.save('10epoch_binaryMask.h5')

# %%
model = custom_unet(input_shape=(512,512,1))
model.load_weights('10epoch_binaryMask.h5')

# %%
def visualise_data(x, y):
  n=4
  dim = int(np.ceil(np.sqrt(n)))
  fig = plt.figure(figsize=(20,10))
  for i in range(n):
    ax = fig.add_subplot(dim, dim, i+1)
    ax.imshow(x[50*i,:,:,0], cmap='gray')
    contours = measure.find_contours(y[50*i,:,:,0], .99)
    for contour in contours:
      ax.plot(contour[:,1], contour[:,0], color='#FB3640', lw=4)
    ax.axis('off')


def visualise_data_and_prediction(x, y, y_pred):
  n=4
  dim = int(np.ceil(np.sqrt(n)))
  fig = plt.figure(figsize=(20,10))
  for i in range(n):
    ax = fig.add_subplot(dim, dim, i+1)
    ax.imshow(x[50*i,:,:,0], cmap='gray')
    contours = measure.find_contours(y[50*i,:,:,0], .99)
    for j,contour in enumerate(contours):
      ax.plot(contour[:,1], contour[:,0], color='#FB3640', lw=4)
    contours = measure.find_contours(y_pred[50*i,:,:,0], .99)
    for contour in contours:
      ax.plot(contour[:,1], contour[:,0], color='#35A7FF', lw=4)
    ax.axis('off')

# %%
y_pred_train = model.predict(x_train) #TODO: predict on the training set
y_pred_train = y_pred_train.astype('float')

# %%
visualise_data_and_prediction(x_train, y_train, y_pred_train)

# %%
y_pred_valid = model.predict(x_valid) #TODO: predict on the validation set
y_pred_valid = y_pred_valid.astype('float') # casting to type float to avoid ValueError later
#print('Dice:')
#print(np.array(dice_coef(y_valid, y_pred_valid.astype('float'))))

# %%
def retrieve_images_for_prediction(data_path, images,num, size=(512,512)):
  x = []
  for i in range(num):
    img = read_nifti_file(data_path+'\\'+images[i])
    img = resize(img,(size[0], size[1], img.shape[-1]))
    for j in range(img.shape[-1]):
      x.append(img[:,:,j])
  x = np.array(x)[:,:,:,np.newaxis]

  return x

# %%
prediction_set = retrieve_images_for_prediction(data_path, images, 5, size=(512,512))

# %%
model = custom_unet(input_shape=(512,512,1))
model.load_weights('10epoch_binaryMask.h5')

# %%
MR_K_predictions = model.predict(prediction_set)
MR_K_predictions = MR_K_predictions.astype('float')

# %%
orig_filename = images[1]
orig_clip_fname = orig_filename[:-4]
print(orig_clip_fname)

new_fname = '%s_PREDICTION_10_epoch.nii' %orig_clip_fname
print(new_fname)

final_path = r'C:\Users\UAB\data\NII_Binarized\Predictions saved'
affine = np.eye(4)
new_set = np.zeros((512,512,96))
test_data = MR_K_predictions[0:96,:,:,0]
for i in range(test_data.shape[0]):
    new_set[:,:,i] = test_data[i,:,:]

nifti_file = nib.Nifti1Image(new_set, affine)
nib.save(nifti_file, os.path.join(final_path, "%s" %new_fname))
# Out:
# 101934_1_96_R_M
# 101934_1_96_R_M_PREDICTION_10_epoch.nii

# %% [markdown]
# # Begin 50 Epoch

# %%
# define the checkpoint
from keras.callbacks import ModelCheckpoint
filepath = "50epoch_binaryMask.h5"
checkpoint = ModelCheckpoint(filepath, monitor='loss', verbose=1, save_best_only=True, mode='min')
callbacks_list = [checkpoint]
model = custom_unet(input_shape=(512, 512, 1))

# %%
model.compile(
  optimizer=tf.keras.optimizers.Adam(learning_rate=3e-4), #TODO: compile the model as described above
  loss=jaccard_distance,
  metrics=[dice_coef])

# %%
history = model.fit(x_train, y_train, 
                    validation_data=(x_valid, y_valid), #TODO: fit the model to the training data, track performance on the validation set and train for 5 epochs.
                    epochs=50)
# Out:
# Epoch 1/50
# 99/99 [==============================] - 47s 377ms/step - loss: 0.3071 - dice_coef: 0.1310 - val_loss: 0.2566 - val_dice_coef: 0.1427
# Epoch 2/50
# 99/99 [==============================] - 35s 350ms/step - loss: 0.2144 - dice_coef: 0.1744 - val_loss: 0.1669 - val_dice_coef: 0.2038
# Epoch 3/50
# 99/99 [==============================] - 35s 353ms/step - loss: 0.1818 - dice_coef: 0.1984 - val_loss: 0.1417 - val_dice_coef: 0.2317
# Epoch 4/50
# 99/99 [==============================] - 35s 354ms/step - loss: 0.1459 - dice_coef: 0.2370 - val_loss: 0.1543 - val_dice_coef: 0.2169
# Epoch 5/50
# 99/99 [==============================] - 35s 354ms/step - loss: 0.1187 - dice_coef: 0.2752 - val_loss: 0.1349 - val_dice_coef: 0.2406
# Epoch 6/50
# 99/99 [==============================] - 35s 354ms/step - loss: 0.0973 - dice_coef: 0.3168 - val_loss: 0.1050 - val_dice_coef: 0.2891
# Epoch 7/50
# 99/99 [==============================] - 35s 355ms/step - loss: 0.0805 - dice_coef: 0.3581 - val_loss: 0.0903 - val_dice_coef: 0.3209
# Epoch 8/50
# 99/99 [==============================] - 35s 355ms/step - loss: 0.0647 - dice_coef: 0.4082 - val_loss: 0.0684 - val_dice_coef: 0.3825
# Epoch 9/50
# 99/99 [==============================] - 35s 354ms/step - loss: 0.0523 - dice_coef: 0.4587 - val_loss: 0.0517 - val_dice_coef: 0.4477
# Epoch 10/50
# 99/99 [==============================] - 35s 354ms/step - loss: 0.0423 - dice_coef: 0.5102 - val_loss: 0.0387 - val_dice_coef: 0.5134
# Epoch 11/50
# 99/99 [==============================] - 35s 353ms/step - loss: 0.0345 - dice_coef: 0.5600 - val_loss: 0.0394 - val_dice_coef: 0.5194
# Epoch 12/50
# 99/99 [==============================] - 35s 353ms/step - loss: 0.0283 - dice_coef: 0.6068 - val_loss: 0.0285 - val_dice_coef: 0.5958
# Epoch 13/50
# 99/99 [==============================] - 35s 354ms/step - loss: 0.0247 - dice_coef: 0.6359 - val_loss: 0.0986 - val_dice_coef: 0.3009
# Epoch 14/50
# 99/99 [==============================] - 35s 354ms/step - loss: 0.0204 - dice_coef: 0.6782 - val_loss: 0.0242 - val_dice_coef: 0.6371
# Epoch 15/50
# 99/99 [==============================] - 35s 354ms/step - loss: 0.0176 - dice_coef: 0.7095 - val_loss: 0.0187 - val_dice_coef: 0.6931
# Epoch 16/50
# 99/99 [==============================] - 35s 354ms/step - loss: 0.0153 - dice_coef: 0.7353 - val_loss: 0.0172 - val_dice_coef: 0.7113
# Epoch 17/50
# 99/99 [==============================] - 36s 361ms/step - loss: 0.0135 - dice_coef: 0.7588 - val_loss: 0.0128 - val_dice_coef: 0.7609
# Epoch 18/50
# 99/99 [==============================] - 35s 357ms/step - loss: 0.0120 - dice_coef: 0.7791 - val_loss: 0.0119 - val_dice_coef: 0.7760
# Epoch 19/50
# 99/99 [==============================] - 35s 353ms/step - loss: 0.0109 - dice_coef: 0.7941 - val_loss: 0.0107 - val_dice_coef: 0.7948
# Epoch 20/50
# 99/99 [==============================] - 35s 354ms/step - loss: 0.0100 - dice_coef: 0.8079 - val_loss: 0.0097 - val_dice_coef: 0.8092
# Epoch 21/50
# 99/99 [==============================] - 35s 354ms/step - loss: 0.0115 - dice_coef: 0.7796 - val_loss: 0.0099 - val_dice_coef: 0.8027
# Epoch 22/50
# 99/99 [==============================] - 35s 354ms/step - loss: 0.0093 - dice_coef: 0.8171 - val_loss: 0.0085 - val_dice_coef: 0.8276
# Epoch 23/50
# 99/99 [==============================] - 35s 354ms/step - loss: 0.0085 - dice_coef: 0.8303 - val_loss: 0.0251 - val_dice_coef: 0.1091
# Epoch 24/50
# 99/99 [==============================] - 35s 353ms/step - loss: 0.0115 - dice_coef: 0.7714 - val_loss: 0.0111 - val_dice_coef: 0.7370
# Epoch 25/50
# 99/99 [==============================] - 35s 352ms/step - loss: 0.0086 - dice_coef: 0.8258 - val_loss: 0.0082 - val_dice_coef: 0.8222
# Epoch 26/50
# 99/99 [==============================] - 35s 353ms/step - loss: 0.0077 - dice_coef: 0.8429 - val_loss: 0.0072 - val_dice_coef: 0.8491
# Epoch 27/50
# 99/99 [==============================] - 35s 353ms/step - loss: 0.0071 - dice_coef: 0.8538 - val_loss: 0.0066 - val_dice_coef: 0.8600
# Epoch 28/50
# 99/99 [==============================] - 35s 354ms/step - loss: 0.0067 - dice_coef: 0.8612 - val_loss: 0.0061 - val_dice_coef: 0.8682
# Epoch 29/50
# 99/99 [==============================] - 35s 353ms/step - loss: 0.0062 - dice_coef: 0.8698 - val_loss: 0.0063 - val_dice_coef: 0.8681
# Epoch 30/50
# 99/99 [==============================] - 36s 360ms/step - loss: 0.0059 - dice_coef: 0.8744 - val_loss: 0.0058 - val_dice_coef: 0.8757
# Epoch 31/50
# 99/99 [==============================] - 36s 362ms/step - loss: 0.0056 - dice_coef: 0.8813 - val_loss: 0.0050 - val_dice_coef: 0.8870
# Epoch 32/50
# 99/99 [==============================] - 35s 359ms/step - loss: 0.0053 - dice_coef: 0.8857 - val_loss: 0.0048 - val_dice_coef: 0.8935
# Epoch 33/50
# 99/99 [==============================] - 35s 355ms/step - loss: 0.0051 - dice_coef: 0.8915 - val_loss: 0.0047 - val_dice_coef: 0.8970
# Epoch 34/50
# 99/99 [==============================] - 35s 355ms/step - loss: 0.0049 - dice_coef: 0.8949 - val_loss: 0.0046 - val_dice_coef: 0.8983
# Epoch 35/50
# 99/99 [==============================] - 35s 354ms/step - loss: 0.0047 - dice_coef: 0.8998 - val_loss: 0.0042 - val_dice_coef: 0.9035
# Epoch 36/50
# 99/99 [==============================] - 35s 354ms/step - loss: 0.0045 - dice_coef: 0.9029 - val_loss: 0.0043 - val_dice_coef: 0.9043
# Epoch 37/50
# 99/99 [==============================] - 35s 355ms/step - loss: 0.0044 - dice_coef: 0.9059 - val_loss: 0.0044 - val_dice_coef: 0.9028
# Epoch 38/50
# 99/99 [==============================] - 35s 355ms/step - loss: 0.0042 - dice_coef: 0.9088 - val_loss: 0.0039 - val_dice_coef: 0.9119
# Epoch 39/50
# 99/99 [==============================] - 35s 355ms/step - loss: 0.0041 - dice_coef: 0.9116 - val_loss: 0.0036 - val_dice_coef: 0.9181
# Epoch 40/50
# 99/99 [==============================] - 35s 355ms/step - loss: 0.0039 - dice_coef: 0.9149 - val_loss: 0.0037 - val_dice_coef: 0.9146
# Epoch 41/50
# 99/99 [==============================] - 35s 354ms/step - loss: 0.0038 - dice_coef: 0.9164 - val_loss: 0.0035 - val_dice_coef: 0.9208
# Epoch 42/50
# 99/99 [==============================] - 35s 355ms/step - loss: 0.0037 - dice_coef: 0.9181 - val_loss: 0.0041 - val_dice_coef: 0.9107
# Epoch 43/50
# 99/99 [==============================] - 35s 354ms/step - loss: 0.0036 - dice_coef: 0.9211 - val_loss: 0.0033 - val_dice_coef: 0.9219
# Epoch 44/50
# 99/99 [==============================] - 35s 353ms/step - loss: 0.0035 - dice_coef: 0.9233 - val_loss: 0.0032 - val_dice_coef: 0.9268
# Epoch 45/50
# 99/99 [==============================] - 35s 353ms/step - loss: 0.0034 - dice_coef: 0.9261 - val_loss: 0.0031 - val_dice_coef: 0.9304
# Epoch 46/50
# 99/99 [==============================] - 35s 353ms/step - loss: 0.0033 - dice_coef: 0.9279 - val_loss: 0.0032 - val_dice_coef: 0.9270
# Epoch 47/50
# 99/99 [==============================] - 35s 353ms/step - loss: 0.0032 - dice_coef: 0.9298 - val_loss: 0.0030 - val_dice_coef: 0.9297
# Epoch 48/50
# 99/99 [==============================] - 35s 353ms/step - loss: 0.0031 - dice_coef: 0.9317 - val_loss: 0.0031 - val_dice_coef: 0.9299
# Epoch 49/50
# 99/99 [==============================] - 35s 353ms/step - loss: 0.0031 - dice_coef: 0.9324 - val_loss: 0.0031 - val_dice_coef: 0.9299
# Epoch 50/50
# 99/99 [==============================] - 35s 353ms/step - loss: 0.0030 - dice_coef: 0.9350 - val_loss: 0.0028 - val_dice_coef: 0.9353

# %%
# %matplotlib inline
plt.plot(range(len(history.history['loss'])), history.history['loss'], '-') #TODO: plot the training loss learning curve
plt.plot(range(len(history.history['val_loss'])), history.history['val_loss'], '-') #TODO: plot the validation loss learning curve
plt.xlabel('epoch')
plt.xlabel('Jaccard loss')

plt.show()

# %%
plt.plot(range(len(history.history['dice_coef'])), history.history['dice_coef'], '-') #TODO: plot the training dice_coef learning curve

plt.plot(range(len(history.history['val_dice_coef'])), history.history['val_dice_coef'], '-') #TODO: plot the validation dice_coef learning curve
plt.xlabel('epoch')
plt.xlabel('Dice coefficient')
# Out:
# Text(0.5, 0, 'Dice coefficient')

# %%
from keras.models import Sequential, load_model
model.save("50epoch_binaryMask.h5")

# %%
model = custom_unet(input_shape=(512,512,1))
model.load_weights("50epoch_binaryMask.h5")

# %%
y_pred_train = model.predict(x_train) #TODO: predict on the training set
y_pred_train = y_pred_train.astype('float') 

visualise_data_and_prediction(x_train, y_train, y_pred_train)
