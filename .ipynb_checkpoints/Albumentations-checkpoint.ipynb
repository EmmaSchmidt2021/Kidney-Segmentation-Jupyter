# %%
import numpy as np
import random

import cv2
from matplotlib import pyplot as plt

import albumentations as A
# %matplotlib inline

# %%
image = np.zeros((512,512,3))

# %%
image[:,:,0] = np.load(r"C:\Users\UAB\data\Mayo\data\MA_385151_3_154_R_50_M.npy")
image[:,:,1] = np.load(r"C:\Users\UAB\data\Mayo\data\MA_385151_3_154_R_50_K.npy")
image[:,:,2] = np.load(r"C:\Users\UAB\data\Mayo\data\MA_385151_3_154_R_50_C.npy")

# %%
plt.imshow(image[:,:,1])

# %%
plt.imshow(image[:,:,0])

# %%
plt.imshow(image[:,:,2])

# %%
def visualize(image):
    plt.figure(figsize=(10, 10))
    plt.axis('off')
    plt.imshow(image)

# %%
transform = A.Compose([
    #A.CLAHE(),
    A.RandomRotate90(),
    A.Transpose(),
    #A.ShiftScaleRotate(shift_limit=0.0625, scale_limit=0.50, rotate_limit=45, p=.75),
    A.Blur(blur_limit=3),
    A.OpticalDistortion(),
    A.GridDistortion(),
    #A.HueSaturationValue(),
])
random.seed(42) 
augmented_image = transform(image=image)['image']
#visualize(augmented_image)

# %%
plt.imshow(augmented_image[:,:,1])

# %%
plt.imshow(augmented_image[:,:,0])

# %%
plt.imshow(augmented_image[:,:,2])

# %%
fig, axs = plt.subplots(2, 3)
axs[0, 0].imshow(image[:,:,0])
axs[0, 0].set_title("orignial image")
axs[0, 1].imshow(image[:,:,1])
axs[0, 1].set_title("origninal kidney mask")
axs[0, 2].imshow(image[:,:,2])
axs[0, 2].set_title("origninal cyst mask")
axs[1, 0].imshow(augmented_image[:,:,0])
axs[1, 0].set_title("augmented image")
axs[1, 1].imshow(augmented_image[:,:,1])
axs[1, 1].set_title("augemented kidney mask")
axs[1, 2].imshow(augmented_image[:,:,2])
axs[1, 2].set_title("augemented cyst mask")
fig.tight_layout()

# %%
img = np.load(r"C:\Users\UAB\data\Emory\data\\EM_245990_1_96_R_52_M.npy")

# %%
plt.imshow(img)

# %%
mask = np.load(r"C:\Users\UAB\data\Mayo\data\MA_385151_3_154_R_50_K.npy")

# %%
from tensorflow.keras.models import Sequential, load_model
import os
import numpy as np
import nibabel as nib
import tensorflow as tf
import matplotlib.pyplot as plt
from skimage import measure
from skimage.transform import resize
from keras_unet.metrics import dice_coef
from keras_unet.models import custom_unet
from keras_unet.losses import jaccard_distance
from sklearn.model_selection import train_test_split
from PIL import Image
from PIL import ImageOps
import fnmatch
import nibabel as nib
import shutil
# %matplotlib inline

# %%
mask_cont = measure.find_contours(mask, 0.8)

# %%
from skimage import data, segmentation
clean_border = segmentation.clear_border(mask).astype(np.uint8)
edges = segmentation.mark_boundaries(mask, clean_border)

# %%
plt.imshow(edges[:,:,1])

# %%
edges[:,:,1].dtype
# Out:
# dtype('float64')

# %%
import numpy as np
import cv2 as cv

# %%
cont = cv.findContours(mask, cv.RETR_TREE, cv.CHAIN_APPROX_SIMPLE)

# %%
plt.imshow(cont)
# Out:
# C:\Users\UAB\anaconda3\envs\TF23\lib\site-packages\matplotlib\cbook\__init__.py:682: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   x = np.array(x, subok=True, copy=copy)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-51-8e66ca07fde1> in <module>
# ----> 1 plt.imshow(cont)
#
# ~\anaconda3\envs\TF23\lib\site-packages\matplotlib\pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, filternorm, filterrad, resample, url, data, **kwargs)
#    2706         filternorm=True, filterrad=4.0, resample=None, url=None,
#    2707         data=None, **kwargs):
# -> 2708     __ret = gca().imshow(
#    2709         X, cmap=cmap, norm=norm, aspect=aspect,
#    2710         interpolation=interpolation, alpha=alpha, vmin=vmin,
#
# ~\anaconda3\envs\TF23\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1436     def inner(ax, *args, data=None, **kwargs):
#    1437         if data is None:
# -> 1438             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1439
#    1440         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~\anaconda3\envs\TF23\lib\site-packages\matplotlib\axes\_axes.py in imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, filternorm, filterrad, resample, url, **kwargs)
#    5521                               resample=resample, **kwargs)
#    5522
# -> 5523         im.set_data(X)
#    5524         im.set_alpha(alpha)
#    5525         if im.get_clip_path() is None:
#
# ~\anaconda3\envs\TF23\lib\site-packages\matplotlib\image.py in set_data(self, A)
#     690         if isinstance(A, PIL.Image.Image):
#     691             A = pil_to_array(A)  # Needed e.g. to apply png palette.
# --> 692         self._A = cbook.safe_masked_invalid(A, copy=True)
#     693
#     694         if (self._A.dtype != np.uint8 and
#
# ~\anaconda3\envs\TF23\lib\site-packages\matplotlib\cbook\__init__.py in safe_masked_invalid(x, copy)
#     680
#     681 def safe_masked_invalid(x, copy=False):
# --> 682     x = np.array(x, subok=True, copy=copy)
#     683     if not x.dtype.isnative:
#     684         # If we have already made a copy, do the byteswap in place, else make a
#
# ValueError: could not broadcast input array from shape (4,) into shape (1,)

# %%
contours, hierarchy = cv2.findContours(mask,cv2.RETR_TREE,cv2.CHAIN_APPROX_NONE)
tmp = np.zeros_like(mask)
boundary = cv2.drawContours(tmp, contours, 0,(255,255,255), -1)
for i in range(1,len(contours)):
    boundary = cv2.drawContours(boundary, contours, i,(255,255,255), -1)

plt.imshow(boundary, cmap = "gray")
