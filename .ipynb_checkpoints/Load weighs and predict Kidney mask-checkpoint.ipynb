# %%
from keras.models import Sequential, load_model
import os
import numpy as np
import nibabel as nib
import tensorflow as tf
import matplotlib.pyplot as plt
from skimage import measure
from skimage.transform import resize
from keras_unet.metrics import dice_coef
from keras_unet.models import custom_unet
from keras_unet.losses import jaccard_distance
from sklearn.model_selection import train_test_split
from PIL import Image
from PIL import ImageOps
import fnmatch
import nibabel as nib
import shutil
# %matplotlib inline

# %%
model = custom_unet(input_shape=(512,512,1))
model.load_weights('my_model.h5')

# %%
def visualise_data(x, y):
  n=4
  dim = int(np.ceil(np.sqrt(n)))
  fig = plt.figure(figsize=(20,10))
  for i in range(n):
    ax = fig.add_subplot(dim, dim, i+1)
    ax.imshow(x[50*i,:,:,0], cmap='gray')
    contours = measure.find_contours(y[50*i,:,:,0], .99)
    for contour in contours:
      ax.plot(contour[:,1], contour[:,0], color='#FB3640', lw=4)
    ax.axis('off')


def visualise_data_and_prediction(x, y, y_pred):
  n=4
  dim = int(np.ceil(np.sqrt(n)))
  fig = plt.figure(figsize=(20,10))
  for i in range(n):
    ax = fig.add_subplot(dim, dim, i+1)
    ax.imshow(x[50*i,:,:,0], cmap='gray')
    contours = measure.find_contours(y[50*i,:,:,0], .99)
    for j,contour in enumerate(contours):
      ax.plot(contour[:,1], contour[:,0], color='#FB3640', lw=4)
    contours = measure.find_contours(y_pred[50*i,:,:,0], .99)
    for contour in contours:
      ax.plot(contour[:,1], contour[:,0], color='#35A7FF', lw=4)
    ax.axis('off')

# %%
def gather_images(data_path):
    images = []
    path = data_path + '\\'
    for f in os.listdir(data_path):
      if '_K' in f:
        continue
      else:
        images.append(f)
        #segmentations.append(f.replace('.nii', '_K.nii'))

    #print(images[0], segmentations[0])
    images = np.array(images)
    #segmentations = np.array(segmentations)

    indices = np.array(range(len(images))) # we will use this in the next step.

    return images

# %%
def read_nifti_file(path):
    nifti_image = nib.load(path)
    nib_data = nifti_image.get_fdata()
    return nib_data

def retrieve_images_for_prediction(data_path, images,num, size=(512,512)):
  x = []
  for i in range(num):
    img = read_nifti_file(data_path+'\\'+images[i])
    img = resize(img,(size[0], size[1], img.shape[-1]))
    for j in range(img.shape[-1]):
      x.append(img[:,:,j])
  x = np.array(x)[:,:,:,np.newaxis]

  return x

# %%
data_path = r'C:\Users\UAB\data\512_AllNII'
images = gather_images(data_path)

# %%
print(images[0])
print(len(images))
# Out:
# 101934_1_96_L_M.nii
# 248

# %%
prediction_set = retrieve_images_for_prediction(data_path, images, 5, size=(512,512))

# %%
print(prediction_set.shape)
# Out:
# (480, 512, 512, 1)

# %%
def visualise_data_pred(x):
  n=4
  dim = int(np.ceil(np.sqrt(n)))
  fig = plt.figure(figsize=(10,10))
  for i in range(n):
    ax = fig.add_subplot(dim, dim, i+1)
    ax.imshow(x[50*i,:,:,0], cmap='gray')
    #contours = measure.find_contours(y[50*i,:,:,0], .99)
    #for contour in contours:
      #ax.plot(contour[:,1], contour[:,0], color='#FB3640', lw=4)
    ax.axis('off')

# %%
visualise_data_pred(prediction_set)

# %%
MR_K_predictions = model.predict(prediction_set)
MR_K_predictions = MR_K_predictions.astype('float')

# %%
def visualise_data(x, y):
  n=4
  dim = int(np.ceil(np.sqrt(n)))
  fig = plt.figure(figsize=(20,10))
  for i in range(n):
    ax = fig.add_subplot(dim, dim, i+1)
    ax.imshow(x[50*i,:,:,0], cmap='gray')
    contours = measure.find_contours(y[50*i,:,:,0], .99)
    for contour in contours:
      ax.plot(contour[:,1], contour[:,0], color='#FB3640', lw=4)
    ax.axis('off')

# %%
visualise_data(prediction_set, MR_K_predictions)

# %%
print(images[0])
# Out:
# 101934_1_96_L_M.nii

# %%
image_og = nib.load(data_path+'\\'+images[0])
image_og = image_og.get_fdata()

# %%
print(image_og.shape[-1])
# Out:
# 96

# %%
orig_filename = images[0]
orig_clip_fname = orig_filename[:-4]
print(orig_clip_fname)
# Out:
# 101934_1_96_L_M

# %%
new_fname = '%s_K.nii' %orig_clip_fname
print(new_fname)
# Out:
# 101934_1_96_L_M_K.nii

# %%
final_path = r'C:\Users\UAB\data\512_AllNII\Kidney Predict 50 epoch'
affine = np.eye(4)
new_set = MR_K_predictions[0:96,:,:,0]
nifti_file = nib.Nifti1Image(new_set, affine)
nib.save(nifti_file, os.path.join(final_path, "3_%s" %new_fname))

# %%
read_in = nib.load(r"C:\Users\UAB\data\512_AllNII\Kidney Predict 50 epoch\3_101934_1_96_L_M_K.nii")

# %%
read_test = read_in.get_fdata()

# %%
print(read_in.shape)
# Out:
# (96, 512, 512)

# %%
plt.imshow(read_test[50,:,:], cmap='gray')

# %%
#read in the real prediction and display 
real_in = nib.load(r"C:\Users\UAB\data\512_AllNII\101934_1_96_L_M_K.nii")
real_in_test = real_in.get_fdata()
print(real_in.shape)
# Out:
# (512, 512, 96)

# %%
plt.imshow(real_in_test[:,:,50], cmap='gray')

# %%
real_in = nib.load(r"C:\Users\UAB\data\512_AllNII\101934_1_96_L_M.nii")
real_in_test = real_in.get_fdata()
print(real_in.shape)
plt.imshow(real_in_test[:,:,50], cmap='gray')
# Out:
# (512, 512, 96)

# %% [markdown]
# ## The masks are saved as (Slice, x, x)
# ## the real masks needed for the cyst will need to be (X,X, slice)

# %%
MR = nib.load(r"C:\Users\UAB\data\512_AllNII\101934_1_96_L_M.nii")
og_K = nib.load(r"C:\Users\UAB\data\512_AllNII\101934_1_96_L_M_K.nii")
pred_K = nib.load(r"C:\Users\UAB\data\512_AllNII\Kidney Predict 50 epoch\3_101934_1_96_L_M_K.nii")

# %%
prediction = pred_K.get_fdata()

# %%
def restack_K_C(image):
    image_data = image.get_fdata()
    image_reslice = np.zeros((512,512, image_data.shape[-1]))
    slices = image_data.shape[0]-1 
    for x in range(slices):
        data_slice = image_data[x,:,:]
        image_reslice[:,:,x]= data_slice

    return image_reslice

# %%
def restack_C_K(image):
    image_data = image.get_fdata()
    image_reslice = np.zeros((image_data.shape[-1], 512, 512))
    slices = image_data.shape[-1]-1 
    for x in range(slices):
        data_slice = image_data[:,:,x]
        image_reslice[x,:,:]= data_slice
    return image_reslice

# %%
restacked_img = restack_K_C(pred_K)

# %%
kidney_mask = restack_C_K(og_K)

# %%
visualise_data_and_prediction(MR, kidney_mask, pred_K)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-79-c323ca171e4d> in <module>
# ----> 1 visualise_data_and_prediction(MR, kidney_mask, pred_K)
#
# <ipython-input-3-ffd1dedde698> in visualise_data_and_prediction(x, y, y_pred)
#      18   for i in range(n):
#      19     ax = fig.add_subplot(dim, dim, i+1)
# ---> 20     ax.imshow(x[50*i,:,:,0], cmap='gray')
#      21     contours = measure.find_contours(y[50*i,:,:,0], .99)
#      22     for j,contour in enumerate(contours):
#
# ~\anaconda3\envs\TF23\lib\site-packages\nibabel\spatialimages.py in __getitem__(self, idx)
#     584         own risk.
#     585         '''
# --> 586         raise TypeError(
#     587             "Cannot slice image objects; consider using `img.slicer[slice]` "
#     588             "to generate a sliced image (see documentation for caveats) or "
#
# TypeError: Cannot slice image objects; consider using `img.slicer[slice]` to generate a sliced image (see documentation for caveats) or slicing image array data with `img.dataobj[slice]` or `img.get_fdata()[slice]`

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-81-8966aefe3230> in <module>
# ----> 1 visualise_data(MR, pred_K)
#
# <ipython-input-22-1e17da58bb23> in visualise_data(x, y)
#       5   for i in range(n):
#       6     ax = fig.add_subplot(dim, dim, i+1)
# ----> 7     ax.imshow(x[50*i,:,:,0], cmap='gray')
#       8     contours = measure.find_contours(y[50*i,:,:,0], .99)
#       9     for contour in contours:
#
# ~\anaconda3\envs\TF23\lib\site-packages\nibabel\spatialimages.py in __getitem__(self, idx)
#     584         own risk.
#     585         '''
# --> 586         raise TypeError(
#     587             "Cannot slice image objects; consider using `img.slicer[slice]` "
#     588             "to generate a sliced image (see documentation for caveats) or "
#
# TypeError: Cannot slice image objects; consider using `img.slicer[slice]` to generate a sliced image (see documentation for caveats) or slicing image array data with `img.dataobj[slice]` or `img.get_fdata()[slice]`
